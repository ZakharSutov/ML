# %%
# %pylab inline --no-import-all
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples = 500, n_features = 2, centers = 4, cluster_std=1.0,
               center_box = (-10.0, 10.0), shuffle = False)
plt.scatter(X[:, 0], X[:, 1], color = np.array(['b', 'r', 'g', 'c'])[y],
            s = 50, alpha = 0.35)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(X)
X_pca = pca.transform(X) # или сразу pca.fit_transform(X)
X_pca.shape
# Out:
# (500, 2)

# %%
def draw_proj_digits(X, y):
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(digits.target[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

draw_proj_digits(X_reduced, digits.target) # Никогда не запускайте эту функцию!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5d6efacf5588> in <cell line: 7>()
#       5                  fontdict={'weight': 'bold', 'size': 9})
#       6
# ----> 7 draw_proj_digits(X_reduced, digits.target) # Никогда не запускайте эту функцию!
#
# NameError: name 'X_reduced' is not defined
